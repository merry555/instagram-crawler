# %%
from pandas import Series, DataFrame
import pandas as pd

# %%
csv_test = pd.read_csv('/Users/jisu/Desktop/DX/data_analytics/Parasite/word_count2/after/2019_oscar_after.csv')

# %%
word_list_1 = []
date_list_1 = []
word_count_1 = 0

word_list_2 = []
date_list_2 = []
word_count_2 = 0

word_list_3 = []
date_list_3 = []
word_count_3 = 0

for i in range(len(csv_test)):
    word_count_1 += csv_test['blackpanther'][i]
    word_list_1.append(word_count_1)
    date_list_1.append(csv_test['date_1'][i])
    
    word_count_2 += csv_test['bohemianrhapsody'][i]
    word_list_2.append(word_count_2)
    date_list_2.append(csv_test['date_2'][i])

    word_count_3 += csv_test['greenbook'][i]
    word_list_3.append(word_count_3)
    date_list_3.append(csv_test['date_3'][i])
    
result = pd.DataFrame({'date_1':date_list_1, 'blackpanther' : word_list_1,
                       'date_2':date_list_2, 'bohemianrhapsody' : word_list_2,
                       'date_3':date_list_3, 'greenbook' : word_list_3
                      })

result.to_csv("/Users/jisu/Desktop/DX/data_analytics/Parasite/result2/oscar_2019_after_cdf.csv", mode='w')
# result.to_csv("/Users/jisu/Desktop/DX/data_analytics/Parasite/result2/oscar_2017_after_cdf.csv", mode='w')

# %%
word_list_1 = []
date_list_1 = []
word_count_1 = 0

word_list_2 = []
date_list_2 = []
word_count_2 = 0

word_list_3 = []
date_list_3 = []
word_count_3 = 0

word_list_4 = []
date_list_4 = []
word_count_4 = 0

word_list_5 = []
date_list_5 = []
word_count_5 = 0

word_list_6 = []
date_list_6 = []
word_count_6 = 0

word_list_7 = []
date_list_7 = []
word_count_7 = 0

word_list_8 = []
date_list_8 = []
word_count_8 = 0

word_list_9 = []
date_list_9 = []
word_count_9 = 0

for i in range(len(csv_test)):
    word_count_1 += csv_test['moonlight'][i]
    word_list_1.append(word_count_1)
    date_list_1.append(csv_test['date_1'][i])
    
    word_count_2 += csv_test['irishman'][i]
    word_list_2.append(word_count_2)
    date_list_2.append(csv_test['date_2'][i])

    word_count_3 += csv_test['jojorabbit'][i]
    word_list_3.append(word_count_3)
    date_list_3.append(csv_test['date_3'][i])
    
    word_count_4 += csv_test['joker'][i]
    word_list_4.append(word_count_4)
    date_list_4.append(csv_test['date_4'][i])

    word_count_5 += csv_test['littlewomen'][i]
    word_list_5.append(word_count_5)
    date_list_5.append(csv_test['date_5'][i])
    
    word_count_6 += csv_test['marriagestory'][i]
    word_list_6.append(word_count_6)
    date_list_6.append(csv_test['date_6'][i])
    
    word_count_7 += csv_test['1917'][i]
    word_list_7.append(word_count_7)
    date_list_7.append(csv_test['date_7'][i])
    
    word_count_8 += csv_test['onceuponatime'][i]
    word_list_8.append(word_count_8)
    date_list_8.append(csv_test['date_8'][i])
    
    word_count_9 += csv_test['parasite'][i]
    word_list_9.append(word_count_8)
    date_list_9.append(csv_test['date_9'][i])

# %%
result = pd.DataFrame({'date_1':date_list_1, 'fordvferrari' : word_list_1, 
                      'date_2':date_list_2, 'irishman' : word_list_2,
                      'date_3':date_list_3, 'jojorabbit' : word_list_3,
                      'date_4':date_list_4, 'joker' : word_list_4,
                      'date_5':date_list_5, 'marriagestory' : word_list_5,
                      'date_6':date_list_6, '1917' : word_list_6,
                      'date_7':date_list_7, 'onceuponatime' : word_list_7,
                      'date_8':date_list_8, 'parasite' : word_list_8})

result.to_csv("/Users/jisu/Desktop/Dx/data_analytics/Parasite/result/oscar_2020_cdf.csv", mode='w')
